# %% [markdown]
# <a href="https://colab.research.google.com/github/Parasavarshini/FMML_LAB_1/blob/main/FMML_Aug'22_M9_L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Foundation of Modern Machine Learning
# ## Module 9: Neural Networks
# ## Lab 2: Using MLP for multiclass classification
# #### Module Coordinator: Shantanu Agrawal

# %% [markdown]
# Till now, we got to know what is MLP, how it can be used for classification. We have done the single class classification in the previous lab session.
#
# In this notebook we will try to use an MLP for multiclass classification on the iris dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data preparation

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %% [markdown]
# # Visualising dataset

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# # Observing the dataset
#
# Thus, we can observe the dataset and see that there are *3 classes, setosa, versicolor, and virginica*.
#
# There are *4 features, sepal width, sepal length, petal width, petal length*.

# %% [markdown]
# # MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# # Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 176.61it/s]

# %% [markdown]
# # Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# # Experiment with the neural network architecture
#
#
# 1.   Try changing the number of hidden layers.
# 2.   Try changing the number of neurons in the hidden layer.
# 3.   Try using a different activation function.
#
#
#
#
# Can you observe any changes?

# %% [markdown]
# answer1:-

# %%
from sklearn.neural_network import MLPClassifier

# Define input data and corresponding labels for different logic gates
# For AND gate
X_and = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_and = [-1, -1, -1, 1]

# For OR gate
X_or = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_or = [-1, 1, 1, 1]

# For NOR gate
X_nor = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_nor = [1, -1, -1, -1]

# Create MLP classifiers for different logic gates with varying number of hidden layers
mlp_and_1layer = MLPClassifier(hidden_layer_sizes=(2,), activation='logistic', max_iter=1000)
mlp_or_2layers = MLPClassifier(hidden_layer_sizes=(2, 2), activation='logistic', max_iter=1000)
mlp_nor_3layers = MLPClassifier(hidden_layer_sizes=(2, 2, 2), activation='logistic', max_iter=1000)

# Train MLP classifiers
mlp_and_1layer.fit(X_and, y_and)
mlp_or_2layers.fit(X_or, y_or)
mlp_nor_3layers.fit(X_nor, y_nor)

# Test the trained classifiers
test_data = [[-1, -1], [-1, 1], [1, -1], [1, 1]]

print("AND Gate Predictions with 1 Hidden Layer:", mlp_and_1layer.predict(test_data))
print("OR Gate Predictions with 2 Hidden Layers:", mlp_or_2layers.predict(test_data))
print("NOR Gate Predictions with 3 Hidden Layers:", mlp_nor_3layers.predict(test_data))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# AND Gate Predictions with 1 Hidden Layer: [-1 -1 -1 -1]
# OR Gate Predictions with 2 Hidden Layers: [1 1 1 1]
# NOR Gate Predictions with 3 Hidden Layers: [-1 -1 -1 -1]

# %% [markdown]
# answer2:-

# %%
from sklearn.neural_network import MLPClassifier

# Define input data and corresponding labels for different logic gates
# For AND gate
X_and = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_and = [-1, -1, -1, 1]

# For OR gate
X_or = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_or = [-1, 1, 1, 1]

# For NOR gate
X_nor = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_nor = [1, -1, -1, -1]

# Create MLP classifiers for different logic gates with varying number of neurons in the hidden layer
mlp_and_1neuron = MLPClassifier(hidden_layer_sizes=(1,), activation='logistic', max_iter=1000)
mlp_or_2neurons = MLPClassifier(hidden_layer_sizes=(2,), activation='logistic', max_iter=1000)
mlp_nor_4neurons = MLPClassifier(hidden_layer_sizes=(4,), activation='logistic', max_iter=1000)

# Train MLP classifiers
mlp_and_1neuron.fit(X_and, y_and)
mlp_or_2neurons.fit(X_or, y_or)
mlp_nor_4neurons.fit(X_nor, y_nor)

# Test the trained classifiers
test_data = [[-1, -1], [-1, 1], [1, -1], [1, 1]]

print("AND Gate Predictions with 1 Neuron in Hidden Layer:", mlp_and_1neuron.predict(test_data))
print("OR Gate Predictions with 2 Neurons in Hidden Layer:", mlp_or_2neurons.predict(test_data))
print("NOR Gate Predictions with 4 Neurons in Hidden Layer:", mlp_nor_4neurons.predict(test_data))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# AND Gate Predictions with 1 Neuron in Hidden Layer: [-1 -1 -1 -1]
# OR Gate Predictions with 2 Neurons in Hidden Layer: [1 1 1 1]
# NOR Gate Predictions with 4 Neurons in Hidden Layer: [ 1 -1 -1 -1]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# answer3:-

# %%
from sklearn.neural_network import MLPClassifier

# Define input data and corresponding labels for different logic gates
# For AND gate
X_and = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_and = [-1, -1, -1, 1]

# For OR gate
X_or = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_or = [-1, 1, 1, 1]

# For NOR gate
X_nor = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
y_nor = [1, -1, -1, -1]

# Create MLP classifiers for different logic gates with ReLU activation function
mlp_and_relu = MLPClassifier(hidden_layer_sizes=(2,), activation='relu', max_iter=1000)
mlp_or_relu = MLPClassifier(hidden_layer_sizes=(2,), activation='relu', max_iter=1000)
mlp_nor_relu = MLPClassifier(hidden_layer_sizes=(2,), activation='relu', max_iter=1000)

# Train MLP classifiers
mlp_and_relu.fit(X_and, y_and)
mlp_or_relu.fit(X_or, y_or)
mlp_nor_relu.fit(X_nor, y_nor)

# Test the trained classifiers
test_data = [[-1, -1], [-1, 1], [1, -1], [1, 1]]

print("AND Gate Predictions with ReLU Activation Function:", mlp_and_relu.predict(test_data))
print("OR Gate Predictions with ReLU Activation Function:", mlp_or_relu.predict(test_data))
print("NOR Gate Predictions with ReLU Activation Function:", mlp_nor_relu.predict(test_data))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# AND Gate Predictions with ReLU Activation Function: [-1 -1 -1  1]
# OR Gate Predictions with ReLU Activation Function: [1 1 1 1]
# NOR Gate Predictions with ReLU Activation Function: [ 1 -1 -1 -1]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
