# %% [markdown]
# <a href="https://colab.research.google.com/github/Parasavarshini/FMML_LAB_1/blob/main/FMML_2022_Module_04_Project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [REQUIRED] Calculate the gradient at the current x
    new_x = previous_x - (step_multiplier * gradient)  # [REQUIRED] Update new_x using the gradient descent formula

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [REQUIRED] Calculate the slope at the new x

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your existing code...

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [REQUIRED] Calculate the gradient at the current x
    new_x = previous_x - (step_multiplier * gradient)  # [REQUIRED] Update new_x using the gradient descent formula

    step_size = abs(new_x - previous_x)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [REQUIRED] Calculate the slope at the new x

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

# Plotting
plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)

# Superimpose the gradient descent points on the cost function plot
plt.scatter(x_list, f(values), color='green', s=100, alpha=0.6)

plt.show()
# Out:
# Loop ran this many times: 50

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2 + 2*x + 1  # [REQUIRED] Replace with the expression for g(x)

def dg(x):
    return 2*x + 2  # [REQUIRED] Replace with the expression for the derivative dg(x)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2 + 2*x + 1  # Replace with the actual expression for g(x)

def dg(x):
    return 2*x + 2  # Replace with the actual expression for dg(x)

# Plotting
plt.figure(figsize=(12, 5))

# Chart 1: Function g(x)
plt.subplot(1, 2, 1)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3)

# Chart 2: Derivative dg(x)
plt.subplot(1, 2, 2)

plt.title('Derivative dg(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)/dx', fontsize=16)

plt.plot(x_2, dg(x_2), color='green', linewidth=3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
import numpy as np
import matplotlib.pyplot as plt

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2 + 2*x + 1  # Replace with the actual expression for g(x)

def dg(x):
    return 2*x + 2  # Replace with the actual expression for dg(x)

# Plotting
plt.figure(figsize=(12, 5))

# Chart 1: Function g(x)
plt.subplot(1, 2, 1)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3)

# Chart 2: Derivative dg(x)
plt.subplot(1, 2, 2)

plt.title('Derivative dg(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)/dx', fontsize=16)

plt.plot(x_2, dg(x_2), color='green', linewidth=3)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2 + 2*x + 1  # Replace with the actual expression for g(x)

def dg(x):
    return 2*x + 2  # Replace with the actual expression for dg(x)

# Plotting
plt.figure(figsize=(12, 5))

# Chart 1: Function g(x)
plt.subplot(1, 2, 1)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3)

# Chart 2: Derivative dg(x)
plt.subplot(1, 2, 2)

plt.title('Derivative dg(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)/dx', fontsize=16)

plt.plot(x_2, dg(x_2), color='green', linewidth=3)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function and its derivative
def g(x):
    return x**2 + 2*x + 1

def dg(x):
    return 2*x + 2

def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# Example usage
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.5, multiplier=0.01, precision=0.0001)

# Output the results
local_min_rounded = round(local_min, 4)
print(f'Local minimum occurs at: {local_min_rounded}')
print(f'Number of steps: {len(list_x)}')

# Plotting the result
plt.figure(figsize=(12, 5))

# Chart 1: Function g(x)
plt.subplot(1, 2, 1)
plt.title('Function g(x) and Gradient Descent', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# Chart 2: Derivative dg(x)
plt.subplot(1, 2, 2)
plt.title('Derivative dg(x) and Gradient Descent', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)/dx', fontsize=16)
plt.plot(x_2, dg(x_2), color='green', linewidth=3)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Local minimum occurs at: -0.9951
# Number of steps: 230

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.9762106678542721
# Number of steps: 90

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=0)

# Plot function and derivative and scatter plot side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break

    return new_x, x_list, slope_list

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is:', len(list_x))
# Out:
# Number of steps is: 119

# %%
# Run gradient descent 3 times
n = 100

# Low gamma
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)

# Mid gamma
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)

# High gamma
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

# Insane gamma
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting the results
plt.figure(figsize=[20, 5])

# Low gamma
plt.subplot(1, 4, 1)
plt.title('Low Gamma (0.0005)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(low_gamma[1], g(np.array(low_gamma[1])), color='red', s=100, alpha=0.6)

# Mid gamma
plt.subplot(1, 4, 2)
plt.title('Mid Gamma (0.001)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(mid_gamma[1], g(np.array(mid_gamma[1])), color='red', s=100, alpha=0.6)

# High gamma
plt.subplot(1, 4, 3)
plt.title('High Gamma (0.002)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(high_gamma[1], g(np.array(high_gamma[1])), color='red', s=100, alpha=0.6)

# Insane gamma
plt.subplot(1, 4, 4)
plt.title('Insane Gamma (0.25)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(insane_gamma[1], g(np.array(insane_gamma[1])), color='red', s=100, alpha=0.6)

plt.tight_layout()
plt.show()

# %%
# Function to calculate reduction in cost
def cost_reduction(y_values):
    return [y_values[i] - y_values[i + 1] for i in range(len(y_values) - 1)]

# Run gradient descent 3 times
n = 100

# Low gamma
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)

# Mid gamma
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)

# High gamma
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

# Insane gamma
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Calculate reduction in cost for each iteration
reduction_low_gamma = cost_reduction(g(np.array(low_gamma[1])))
reduction_mid_gamma = cost_reduction(g(np.array(mid_gamma[1])))
reduction_high_gamma = cost_reduction(g(np.array(high_gamma[1])))
reduction_insane_gamma = cost_reduction(g(np.array(insane_gamma[1])))

# Plotting the results
plt.figure(figsize=[20, 5])

# Low gamma
plt.subplot(1, 4, 1)
plt.title('Low Gamma (0.0005)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost Reduction', fontsize=16)
plt.plot(reduction_low_gamma, marker='o')

# Mid gamma
plt.subplot(1, 4, 2)
plt.title('Mid Gamma (0.001)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost Reduction', fontsize=16)
plt.plot(reduction_mid_gamma, marker='o')

# High gamma
plt.subplot(1, 4, 3)
plt.title('High Gamma (0.002)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost Reduction', fontsize=16)
plt.plot(reduction_high_gamma, marker='o')

# Insane gamma
plt.subplot(1, 4, 4)
plt.title('Insane Gamma (0.25)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost Reduction', fontsize=16)
plt.plot(reduction_insane_gamma, marker='o')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function and its derivative
def g(x):
    return x**2 + 2*x + 1

def dg(x):
    return 2*x + 2

# Gradient Descent function
def gradient_descent(derivative_func, initial_guess, multiplier=0.1, precision=0.00001, max_iter=500):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]
    cost_list = [g(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))
        cost_list.append(g(new_x))

        if step_size < precision:
            break

    return new_x, x_list, slope_list, cost_list

# %%
import numpy as np

# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array:', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid:', x_4.shape)
# Out:
# Shape of X array: (200,)
# Array after meshgrid: (200, 200)

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
from sympy import symbols, diff

# Define symbols
a, b = symbols('x y')

# Modify the cost function (replace with your desired function)
new_cost_function = a**2 + 2*b

# Print the modified cost function
print('Our modified cost function is:', new_cost_function)

# Compute a different derivative (replace with your desired derivative)
new_derivative = diff(new_cost_function, b)

# Print the modified derivative
print('Partial derivative wrt y is:', new_derivative)

# Evaluate the modified function at a different point (replace with your desired point)
new_point_value = new_cost_function.evalf(subs={a: 1.5, b: -0.5})

# Print the modified function's value at the specified point
print('Value of the modified function at x=1.5, y=-0.5 is:', new_point_value)
# Out:
# Our modified cost function is: x**2 + 2*y
# Partial derivative wrt y is: 2
# Value of the modified function at x=1.5, y=-0.5 is: 1.25000000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
import numpy as np
from sympy import symbols, diff

# Define symbols and the cost function
a, b = symbols('x y')
f = a**2 + 2*b  # Replace this with your desired cost function

# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # Initial guess

for n in range(max_iter):
    # Compute gradients
    gradient_x = diff(f, a).evalf(subs={a: params[0], b: params[1]})
    gradient_y = diff(f, b).evalf(subs={a: params[0], b: params[1]})
    gradients = np.array([gradient_x, gradient_y])

    # Update parameters using gradient descent
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f.evalf(subs={a: params[0], b: params[1]}))
# Out:
# Values in gradient array: [1.57835979496953e-48 2.00000000000000]
# Minimum occurs at x value of: 6.31343917987813e-49
# Minimum occurs at y value of: -99.0000000000009
# The cost is: -198.000000000002

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    # Partial derivative of the cost function with respect to x
    return 2 * x

def fpy(x, y):
    # Partial derivative of the cost function with respect to y
    return 2

# %%
from sympy import symbols, diff

# Define symbols
x, y = symbols('x y')

# Define the cost function
f = x**2 + 2*y  # Replace with your desired cost function

# Define the partial derivatives
fpx = diff(f, x)
fpy = diff(f, y)

# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess

for n in range(max_iter):
    gradient_x = fpx.evalf(subs={x: params[0], y: params[1]})
    gradient_y = fpy.evalf(subs={x: params[0], y: params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f.evalf(subs={x: params[0], y: params[1]}))
# Out:
# Values in gradient array: [1.57835979496953e-48 2.00000000000000]
# Minimum occurs at x value of: 6.31343917987813e-49
# Minimum occurs at y value of: -99.0000000000009
# The cost is: -198.000000000002

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
from sympy import symbols, diff

# Define symbols
x, y = symbols('x y')

# Define the cost function
f = x**2 + 2*y  # Replace with your desired cost function

# Define the partial derivatives
fpx = diff(f, x)
fpy = diff(f, y)

# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0])  # initial guess
values_array = params.reshape(1, 2)

for n in range(max_iter):
    gradient_x = fpx.evalf(subs={x: params[0], y: params[1]})
    gradient_y = fpy.evalf(subs={x: params[0], y: params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f.evalf(subs={x: params[0], y: params[1]}))
# Out:
# Values in gradient array: [1.86728200599645e-19 2.00000000000000]
# Minimum occurs at x value of: 7.46912802398578e-20
# Minimum occurs at y value of: -39.0000000000000
# The cost is: -78.0000000000000

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np

# Assuming x_4, y_4, f(x_4, y_4), and values_array are defined

# Create a meshgrid for x and y values
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)

# Define your function f(x, y)
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Create a 3D plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Plot the surface
ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

# Scatter plot for values_array
values_array = np.random.rand(50, 2) * 10 - 5  # Example random values
ax.scatter(values_array[:, 0], values_array[:, 1], f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
