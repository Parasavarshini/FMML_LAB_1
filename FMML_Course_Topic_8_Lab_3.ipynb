# %% [markdown]
# <a href="https://colab.research.google.com/github/Parasavarshini/FMML_LAB_1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-14 15:23:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   155MB/s    in 0.4s
#
# 2024-05-14 15:23:05 (155 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 27713  1704.03217v1  Initializing optical flow field by either spar...    cs
# 22725  1705.07178v2  Inference of latent feature models in the Baye...  stat
# 10157  1709.08430v1  In this paper we focus on developing a control...    cs
# 22129  1501.02844v1  Item response theory (IRT) models for categori...  stat
# 14698   1006.3787v7  This companion paper complements the main DEFT...    cs
# ...             ...                                                ...   ...
# 22157  1506.02520v1  The subdifferential of convex functions of the...  stat
# 21716   1010.4945v1  A density ratio is defined by the ratio of two...  stat
# 11263  1506.06962v1  Graphs are commonly used to characterise inter...  stat
# 6715   1705.08051v1  Point processes are becoming very popular in m...    cs
# 4910   1701.04113v1  The combinatorial explosion that plagues plann...    cs
#
#                                                    title  year  \
# 27713  Pyramidal Gradient Matching for Optical Flow E...  2017
# 22725   Accelerated Inference for Latent Variable Models  2017
# 10157  Towards continuous control of flippers for a m...  2017
# 22129  SPRITE: A Response Model For Multiple Choice T...  2015
# 14698  Complete Complementary Results Report of the M...  2010
# ...                                                  ...   ...
# 22157  Convex recovery of tensors using nuclear norm ...  2015
# 21716  f-divergence estimation and two-sample homogen...  2010
# 11263        Graphs in machine learning: an introduction  2015
# 6715   Wasserstein Learning of Deep Generative Point ...  2017
# 4910   Near Optimal Behavior via Approximate State Ab...  2017
#
#                                                 keywords
# 27713  [initializing, descriptor, particularly, captu...
# 22725  [inference, nonparametric, generally, difficul...
# 10157  [developing, algorithm, reinforcement, determi...
# 22129  [categorical, educational, computerized, psych...
# 14698  [companion, complements, describing, challenge...
# ...                                                  ...
# 22157  [subdifferential, functions, optimization, aut...
# 21716  [probability, densities, inference, parametric...
# 11263  [characterise, interactions, straightforward, ...
# 6715   [processes, asynchronous, sequential, mathemat...
# 4910   [combinatorial, explosion, reinforcement, algo...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 27713    [initializing, descriptor, particularly, captu...
# 22725    [inference, nonparametric, generally, difficul...
# 10157    [developing, algorithm, reinforcement, determi...
# 22129    [categorical, educational, computerized, psych...
# 14698    [companion, complements, describing, challenge...
#                                ...
# 3546     [convolutional, advancement, promising, perfor...
# 28064    [articulated, interaction, contemporary, capit...
# 20494    [rebalancing, repositioning, commodity, perfor...
# 11889    [collecting, knowledge, initially, introduce, ...
# 5642     [representations, justification, multitask, il...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8904 words.
# Out of those 4601 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c70dd3d-5643-48ef-a65f-7d5fd1c26b16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c70dd3d-5643-48ef-a65f-7d5fd1c26b16")) {                    Plotly.newPlot(                        "4c70dd3d-5643-48ef-a65f-7d5fd1c26b16",                        [{"x":["therefore","capturing","particularly","initializing","contribution","different","complexity","framework","information","filtering","direction","experimental","descriptor","efficient","enhancements","published","pyramidal","effective","estimation","displacements","gradients","generally","computationally","dimensional","tractable","theoretically","especially","according","integration","likelihood","guaranteed","locations","performed","accelerate","dimensions","predictive","assignments","difficult","nonparametric","inference","posterior","distribution","accelerated","attractive","proposing","simulation","flexibility","reinforcement","successful","increased","notwithstanding","developing","observable","continuous","situations","controller","difficulty","complications","environments","partially","algorithm","circumstances","deterministic","computerized","synthetic","demonstrate","assumption","impractical","restrictive","categorical","psychological","parameters","educational","performance","scenarios","categories","stochastic","methodology","assumptions","furthermore","unordered","interpretable","interpret","incorrectness","pipelines","competition","conducted","resulting","highlighting","particular","subsequent","describing","experiments","complementary","application","classical","complements","identification","companion","challenge","publication","iteration","conditions","distributions","arbitrarily","clustering","condition","integrable","hypothesis","complement","depending","theoretical","satisfies","practical","viewpoints","necessarily","quantization","introduce","literature","beneficial","supervised","resilient","euclidean","widespread","corruptions","functions","applications","developed","discovery","piecewise","empirical","guarantees","sufficient","discovering","algorithms","generalizing","convergence","incorporating","penalties","annotation","representations","representative","computing","quadratic","retrieval","conventional","availability","reconstruction","structure","dictionaries","optimizing","structures","recovering","unsupervised","refinement","confidence","distributed","monolingual","analyzing","autoencoders","compatible","hypothesize","technique","semantically","qualitative","approaches","autoencoder","preliminary","principle","languages","adversarial","developments","typically","fundamental","prescriptive","interactions","tournament","heterogeneous","specifically","effectiveness","tournaments","consistently","representation","autonomous","exploration","highlight","automated","engineered","adversaries","collaborations","sometimes","abstraction","successfully","performing","necessary","rationality","equilibrium","optimization","applicability","inferences"],"y":[153,36,98,5,60,769,244,561,706,54,63,410,33,402,2,50,2,256,212,2,40,71,97,171,38,47,110,95,48,65,27,38,132,26,35,54,11,134,16,257,47,232,9,16,21,65,27,123,77,41,3,66,22,116,58,17,49,3,91,49,817,10,37,5,139,587,65,10,7,15,13,255,4,877,94,64,142,65,66,163,1,35,28,1,12,28,69,146,8,323,28,38,640,35,249,101,4,96,4,138,8,45,123,126,13,149,57,0,53,17,33,143,20,151,11,19,30,349,123,13,188,2,38,9,2,199,432,195,61,14,134,70,61,22,598,10,125,50,6,57,235,21,130,22,107,122,34,92,362,20,45,155,16,149,17,35,107,13,61,25,16,15,228,36,52,454,23,44,55,105,103,20,108,88,2,75,5,33,147,222,2,35,336,70,53,30,92,12,5,5,29,21,76,72,86,6,14,330,39,10],"type":"bar"},{"x":["therefore","capturing","particularly","initializing","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4601,), (4601, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.8813559322033899);'>Translation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>with</span> <span style=''>Global</span> <span style=''>Sentence</span> <span style='background-color:rgba(0, 255, 0, 0.3359840954274354);'>Representation</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Statistical</span> <span style=''>machine</span> <span style='background-color:rgba(0, 255, 0, 0.8813559322033899);'>translation</span> <span style=''>models</span> <span style=''>have</span> <span style=''>made</span> <span style=''>great</span> <span style=''>progress</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3764705882352941);'>improving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.8813559322033899);'>translation</span> <span style=''>quality</span> <span style=''>However</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>models</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.8813559322033899);'>translation</span> <span style=''>with</span> <span style=''>only</span> <span style=''>the</span> <span style=''>source</span> <span style=''>and</span> <span style=''>target</span> <span style=''>side</span> <span style=''>local</span> <span style=''>context</span> <span style='background-color:rgba(0, 255, 0, 0.30861909175162194);'>information</span> <span style=''>In</span> <span style=''>practice</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinguishing</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>translations</span> <span style=''>from</span> <span style=''>bad</span> <span style=''>ones</span> <span style=''>does</span> <span style=''>not</span> <span style=''>only</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>local</span> <span style=''>features</span> <span style=''>but</span> <span style=''>also</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>the</span> <span style=''>global</span> <span style=''>sentence</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.30861909175162194);'>information</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>the</span> <span style=''>source</span> <span style=''>side</span> <span style=''>global</span> <span style=''>sentence</span> <span style=''>level</span> <span style=''>features</span> <span style=''>for</span> <span style=''>target</span> <span style=''>side</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.8813559322033899);'>translation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>bilingually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style=''>chunk</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.6026200873362445);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>sentence</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.33903133903133903);'>representations</span> <span style=''>With</span> <span style=''>the</span> <span style=''>sentence</span> <span style=''>level</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3359840954274354);'>representation</span> <span style=''>we</span> <span style=''>further</span> <span style=''>design</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>and</span> <span style=''>Memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Significant</span> <span style=''>Pattern</span> <span style=''>Mining</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Permutation</span> <span style=''>Testing</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Westfall</span> <span style=''>Young</span> <span style=''>light</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detecting</span> <span style=''>patterns</span> <span style=''>such</span> <span style=''>as</span> <span style=''>itemsets</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subgraphs</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>enriched</span> <span style=''>in</span> <span style=''>one</span> <span style=''>of</span> <span style=''>two</span> <span style=''>classes</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>corrects</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>rigorously</span> <span style=''>for</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>patterns</span> <span style=''>through</span> <span style=''>the</span> <span style=''>Westfall</span> <span style=''>Young</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>the</span> <span style=''>null</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequencies</span> <span style=''>in</span> <span style=''>each</span> <span style=''>class</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutations</span> <span style=''>In</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>Westfall</span> <span style=''>Young</span> <span style=''>light</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dramatically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>the</span> <span style=''>current</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>approach</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>both</span> <span style=''>runtime</span> <span style=''>and</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>on</span> <span style=''>popular</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>for</span> <span style=''>pattern</span> <span style=''>mining</span> <span style=''>The</span> <span style=''>key</span> <span style=''>to</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>is</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Arbitrary</span> <span style=''>Sum</span> <span style=''>Product</span> <span style=''>Network</span> <span style=''>Leaves</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Maximization</span> <br/><br/><span style=''>Sum</span> <span style=''>Product</span> <span style=''>Networks</span> <span style=''>with</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>at</span> <span style=''>the</span> <span style=''>leaves</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style=''>powerful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>However</span> <span style=''>while</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>internal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>has</span> <span style=''>been</span> <span style=''>amply</span> <span style=''>studied</span> <span style=''>learning</span> <span style=''>complex</span> <span style=''>leaf</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style=''>an</span> <span style=''>open</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>only</span> <span style=''>few</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>in</span> <span style=''>special</span> <span style=''>cases</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>method</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>very</span> <span style=''>large</span> <span style=''>class</span> <span style=''>of</span> <span style=''>leaf</span> <span style='background-color:rgba(255, 0, 0, 0.30386740331491713);'>distributions</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Maximization</span> <span style=''>The</span> <span style=''>EM</span> <span style=''>updates</span> <span style=''>have</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>simple</span> <span style=''>weighted</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5094339622641508);'>likelihood</span> <span style=''>problems</span> <span style=''>allowing</span> <span style=''>to</span> <span style=''>use</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>learned</span> <span style=''>with</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5094339622641508);'>likelihood</span> <span style=''>even</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximately</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>cost</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style=''>size</span> <span style=''>and</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Recovering</span> <span style=''>Latent</span> <span style=''>Signals</span> <span style=''>from</span> <span style=''>a</span> <span style=''>Mixture</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Measurements</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Prior</span> <br/><br/><span style=''>In</span> <span style=''>sensing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>sensors</span> <span style=''>cannot</span> <span style=''>always</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>quantity</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>at</span> <span style=''>the</span> <span style=''>required</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sometimes</span> <span style=''>they</span> <span style=''>can</span> <span style=''>only</span> <span style=''>acquire</span> <span style=''>a</span> <span style=''>blurred</span> <span style=''>version</span> <span style=''>of</span> <span style=''>it</span> <span style=''>due</span> <span style=''>the</span> <span style=''>sensors</span> <span style=''>transfer</span> <span style=''>function</span> <span style=''>To</span> <span style=''>recover</span> <span style=''>latent</span> <span style=''>signals</span> <span style=''>when</span> <span style=''>only</span> <span style=''>noisy</span> <span style=''>mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>of</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>mixture</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>(GPMM)</span> <span style=''>which</span> <span style=''>models</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>signal</span> <span style=''>as</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style=''>and</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>such</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>to</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>noisy</span> <span style=''>mixture</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>how</span> <span style=''>to</span> <span style=''>train</span> <span style=''>GPMM</span> <span style=''>that</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>of</span> <span style=''>the</span> <span style=''>GP</span> <span style=''>and</span> <span style=''>the</span> <span style=''>mixing</span> <span style=''>weights</span> <span style=''>and</span> <span style=''>how</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>signal</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12677556818181818)
# 	challenging (0.10227272727272728)
# 	segmentation (0.07173295454545454)
# 	architecture (0.08948863636363637)
# 	information (0.2507102272727273)
# 	experimental (0.1455965909090909)
# 	detection (0.12215909090909091)
# 	convolutional (0.13032670454545456)
# 	different (0.27308238636363635)
# 	recognition (0.13458806818181818)
#
# Some Statistics words are:
# 	stochastic (0.12903225806451613)
# 	variables (0.13608870967741934)
# 	algorithm (0.38961693548387094)
# 	estimation (0.17540322580645162)
# 	theoretical (0.15221774193548387)
# 	statistical (0.15826612903225806)
# 	distribution (0.18800403225806453)
# 	inference (0.19959677419354838)
# 	dimensional (0.1814516129032258)
# 	regression (0.171875)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9c8467e3-fad7-49d7-96b7-024f0f8dfa30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c8467e3-fad7-49d7-96b7-024f0f8dfa30")) {                    Plotly.newPlot(                        "9c8467e3-fad7-49d7-96b7-024f0f8dfa30",                        [{"x":["therefore","capturing","particularly","initializing","contribution","different","complexity","framework","information","filtering","direction","experimental","descriptor","efficient","enhancements","published","pyramidal","effective","estimation","displacements","gradients","generally","computationally","dimensional","tractable","theoretically","especially","according","integration","likelihood","guaranteed","locations","performed","accelerate","dimensions","predictive","assignments","difficult","nonparametric","inference","posterior","distribution","accelerated","attractive","proposing","simulation","flexibility","reinforcement","successful","increased","notwithstanding","developing","observable","continuous","situations","controller","difficulty","complications","environments","partially","algorithm","circumstances","deterministic","computerized","synthetic","demonstrate","assumption","impractical","restrictive","categorical","psychological","parameters","educational","performance","scenarios","categories","stochastic","methodology","assumptions","furthermore","unordered","interpretable","interpret","incorrectness","pipelines","competition","conducted","resulting","highlighting","particular","subsequent","describing","experiments","complementary","application","classical","complements","identification","companion","challenge","publication","iteration","conditions","distributions","arbitrarily","clustering","condition","integrable","hypothesis","complement","depending","theoretical","satisfies","practical","viewpoints","necessarily","quantization","introduce","literature","beneficial","supervised","resilient","euclidean","widespread","corruptions","functions","applications","developed","discovery","piecewise","empirical","guarantees","sufficient","discovering","algorithms","generalizing","convergence","incorporating","penalties","annotation","representations","representative","computing","quadratic","retrieval","conventional","availability","reconstruction","structure","dictionaries","optimizing","structures","recovering","unsupervised","refinement","confidence","distributed","monolingual","analyzing","autoencoders","compatible","hypothesize","technique","semantically","qualitative","approaches","autoencoder","preliminary","principle","languages","adversarial","developments","typically","fundamental","prescriptive","interactions","tournament","heterogeneous","specifically","effectiveness","tournaments","consistently","representation","autonomous","exploration","highlight","automated","engineered","adversaries","collaborations","sometimes","abstraction","successfully","performing","necessary","rationality","equilibrium","optimization","applicability","inferences","improvement","constructed","invertible","specifying","scalability","approximate","restriction","normalizing","approximations","variational","transformed","posteriors","transformations","constructing","advantages","infinitesimal","amortized","significant","structured","occurring","multimodal","bijective","accurately","processes","spatially","frequently","inclusion","hyperparameters","benchmark","producing","cumulative","efficiently","expensive","stationary","challenging","automatically","consistency","weighting","consequences","simulated","percentage","illustrated","minimization","regression","existence","equivalent","universal","combination","simulates","topologies","conversation","iteratively","communicati ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	integrable
# 	infinitesimal
# 	distinguishability
# 	multisensor
# 	unnecessarily
# 	precludes
# 	uncorrupted
# 	psychiatric
# 	schizophrenia
# 	endpoints
# 	degeneration
# 	clarifies
# 	dendrogram
# 	stragglers
# 	subgaussian
# 	distributionally
# 	thermostats
# 	circumvents
# 	timeseries
# 	nonstationarity
# Some words which never appear in Statistics papers:
# 	notwithstanding
# 	monolingual
# 	tournaments
# 	collaborations
# 	colorization
# 	syntactical
# 	categorial
# 	deduction
# 	antecedents
# 	credibility
# 	conflicts
# 	originates
# 	concatenation
# 	formalisms
# 	decidability
# 	unregistered
# 	binocular
# 	monocular
# 	prefetching
# 	abstractive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.052409877598364e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
